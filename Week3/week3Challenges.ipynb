# %%
import random
def adder(x,y):
    '''adds two values returns a sum'''
    return x+y
def timesEm(x,y):
    '''Multiplies two values'''
    return x*y
def divEm(x,y):
    '''return the quotient'''
    return x/y

#num1 = int(input('Num1:'))
#num2 = int(input('Num2:'))
for i in range(5):
num1 =random.randint(1,13)
num2 =random.randint(1,13)

answer = int(input(f'{num1} *{num2} = '))

# %%
print(f'{adder(3,5)}   |   {timesEm(4,6)}')
# Out:
# 8   |   24

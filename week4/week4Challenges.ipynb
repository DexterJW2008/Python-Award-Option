# %%
'''subjects = []
for i in range(6): 
    subject = input(f"Enter a subject {i+1}: ")
    topic =input(f'Enter the topic for {subject}: ')
    subjects.append((subject,topic))
print(subjects)'''
# Out:
# [('HIstory', 'battle of hasting'), ('Geog', 'Global migration'), ('Maths', 'Trig'), ('Chem', 'Bonds'), ('Phy', 'Moments'), ('Comp', 'Programming')]

# %%
subs = [('Hist', 'battle of hasting'), ('Geog', 'Global migration'), ('Maths', 'Trig'), ('Chem', 'Bonds'), ('Phy', 'Moments'), ('Comp', 'Programming')]
for i in range(len(subs)):
    print(f'{subs[i][0]}\t{subs[i][1]}')
tofind = input("Enter a subject to find: ")
for i in range(len(sub)):
    if subs[i][0].lower() ==tofind:
        print("Found")
# Out:
# Hist	battle of hasting
# Geog	Global migration
# Maths	Trig
# Chem	Bonds
# Phy	Moments
# Comp	Programming
